# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc

# %%
# params

loadLoc0 = "/scratch/hcm7920/amb0/data/"
loadLoc1 = "/scratch/hcm7920/amb100/data/"

nx = 500
ny = 500
nz = 50

# %%
# load data
data = nc.Dataset(loadLoc0+"diagsDynamics.nc")
vort = data["momVort3"]

# %%
# load other data
data = nc.Dataset(loadLoc1+"diagsDynamics.nc")
vort1=data["momVort3"]

# %%
ts = 100
levs = [0,3,7,10,15,20]

plt.figure(figsize=(8,5))

for level in levs:
    hist, binEdges = np.histogram(vort1[ts,level,:,:],bins=100)
    plt.stairs(np.log(hist+1),binEdges,label=f"level = {level}")
plt.legend()
plt.title(f"Day {ts} of 365, Max ice")
# Out:
# Text(0.5, 1.0, 'Day 100 of 365, Max ice')

# %%
ts = 100
levs = [0,3,7,10,15,20]

plt.figure(figsize=(8,5))

for level in levs:
    hist, binEdges = np.histogram(vort[ts,level,:,:],bins=100)
    plt.stairs(np.log(hist+1),binEdges,label=f"level = {level}")
plt.legend()
plt.title(f"Day {ts} of 365, No ice")
# Out:
# Text(0.5, 1.0, 'Day 100 of 365, No ice')

# %%
ts = 100
levs = [0,10,15,20]

colors = plt.cm.viridis(np.linspace(0,0.95,len(levs)))
plt.figure(figsize=(8,5))

for ix in range(len(levs)):
    level = levs[ix]
    
    hist, binEdges = np.histogram(vort[ts,level,:,:],bins=100)
    plt.stairs(np.log(hist+1),binEdges, 
               label=f"level {level}, ice free",
               color=colors[ix], linestyle="solid")
    
    hist, binEdges = np.histogram(vort1[ts,level,:,:],bins=100)
    plt.stairs(np.log(hist+1),binEdges, 
               label=f"level {level}, max ice",
               color=colors[ix], linestyle="dashed")
plt.legend()
plt.title(f"")
# Out:
# Text(0.5, 1.0, '')
